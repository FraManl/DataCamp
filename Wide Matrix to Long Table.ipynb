# %%
import numpy as np
import pandas as pd
import re as re

sheet =  "Initiatives"
data_file = "D:\\Users\T0230575\Desktop\Consolidation MYB A20 V14.xlsm"

cols_to_skip = [0]
cols = [i for i in range(9) if i not in cols_to_skip]

dt = pd.read_excel(data_file, 
                   sheet_name = sheet,
                   header = [0], 
                   keep_default_na = True, 
                   skiprows = 9,
                   index = False
                  )

dt = dt.drop(['Unnamed: 0','e-Acq Id (SAV)','Custom Ref','ID','Project Name','Origin of Action',
              'Nature of Action','Initiator of Action','NRC Validation Status',
              'Country / Region','IL / PVET','Action owner','Finance controller',
              'Currency','Recurring / Non-Recurring',
              'Spend 2020 (M€)','Saving Objectives (M€) PPV','NRC (M€) NRC'], axis=1)

dt.rename(columns = {'Action of Competitiveness':'Action_of_competitiveness'}, inplace = True)
dataset_cleaned = dt.fillna(0)
dataset_cleaned = dataset_cleaned[dataset_cleaned.Action_of_competitiveness != 0]

fields = ['Action_of_competitiveness','Cat','Seg', 
         'Transverse oth_PPV_2019','Transverse oth_PPV_2020','Transverse oth_PPV_2021','Transverse oth_PPV_2022',
         'Transverse oth_NRC_2019','Transverse oth_NRC_2020','Transverse oth_NRC_2021','Transverse oth_NRC_2022',
         'Transverse avs_PPV_2019','Transverse avs_PPV_2020','Transverse avs_PPV_2021','Transverse avs_PPV_2022',
         'Transverse avs_NRC_2019','Transverse avs_NRC_2020','Transverse avs_NRC_2021','Transverse avs_NRC_2022',
         'FLX_PPV_2019','FLX_PPV_2020','FLX_PPV_2021','FLX_PPV_2022','FLX_NRC_2019','FLX_NRC_2020','FLX_NRC_2021',
         'FLX_NRC_2022','IFE_PPV_2019','IFE_PPV_2020','IFE_PPV_2021','IFE_PPV_2022','IFE_NRC_2019','IFE_NRC_2020',
         'IFE_NRC_2021','IFE_NRC_2022','ELS_PPV_2019','ELS_PPV_2020','ELS_PPV_2021','ELS_PPV_2022','ELS_NRC_2019',
         'ELS_NRC_2020','ELS_NRC_2021','ELS_NRC_2022','MIS_PPV_2019','MIS_PPV_2020','MIS_PPV_2021','MIS_PPV_2022',
         'MIS_NRC_2019','MIS_NRC_2020','MIS_NRC_2021','MIS_NRC_2022','TTS_PPV_2019','TTS_PPV_2020','TTS_PPV_2021',
         'TTS_PPV_2022','TTS_NRC_2019','TTS_NRC_2020','TTS_NRC_2021','TTS_NRC_2022','Transverse las_PPV_2019',
         'Transverse las_PPV_2020','Transverse las_PPV_2021','Transverse las_PPV_2022','Transverse las_NRC_2019',
         'Transverse las_NRC_2020','Transverse las_NRC_2021','Transverse las_NRC_2022','ATM_PPV_2019','ATM_PPV_2020',
         'ATM_PPV_2021','ATM_PPV_2022','ATM_NRC_2019','ATM_NRC_2020','ATM_NRC_2021','ATM_NRC_2022','AOW_PPV_2019',
         'AOW_PPV_2020','AOW_PPV_2021','AOW_PPV_2022','AOW_NRC_2019','AOW_NRC_2020','AOW_NRC_2021','AOW_NRC_2022',
         'OME_PPV_2019','OME_PPV_2020','OME_PPV_2021','OME_PPV_2022','OME_NRC_2019','OME_NRC_2020','OME_NRC_2021',
         'OME_NRC_2022','VTS_PPV_2019','VTS_PPV_2020','VTS_PPV_2021','VTS_PPV_2022','VTS_NRC_2019','VTS_NRC_2020',
         'VTS_NRC_2021','VTS_NRC_2022','SRA_PPV_2019','SRA_PPV_2020','SRA_PPV_2021','SRA_PPV_2022','SRA_NRC_2019',
         'SRA_NRC_2020','SRA_NRC_2021','SRA_NRC_2022','Transverse dms_PPV_2019','Transverse dms_PPV_2020',
         'Transverse dms_PPV_2021','Transverse dms_PPV_2022','Transverse dms_NRC_2019','Transverse dms_NRC_2020',
         'Transverse dms_NRC_2021','Transverse dms_NRC_2022','AWS_PPV_2019','AWS_PPV_2020','AWS_PPV_2021','AWS_PPV_2022',
         'AWS_NRC_2019','AWS_NRC_2020','AWS_NRC_2021','AWS_NRC_2022','ECS_PPV_2019','ECS_PPV_2020','ECS_PPV_2021',
         'ECS_PPV_2022','ECS_NRC_2019','ECS_NRC_2020','ECS_NRC_2021','ECS_NRC_2022','ISR_PPV_2019','ISR_PPV_2020',
         'ISR_PPV_2021','ISR_PPV_2022','ISR_NRC_2019','ISR_NRC_2020','ISR_NRC_2021','ISR_NRC_2022','UWS_PPV_2019',
         'UWS_PPV_2020','UWS_PPV_2021','UWS_PPV_2022','UWS_NRC_2019','UWS_NRC_2020','UWS_NRC_2021','UWS_NRC_2022',
         'Transverse six_PPV_2019','Transverse six_PPV_2020','Transverse six_PPV_2021','Transverse six_PPV_2022',
         'Transverse six_NRC_2019','Transverse six_NRC_2020','Transverse six_NRC_2021','Transverse six_NRC_2022',
         'CIC_PPV_2019','CIC_PPV_2020','CIC_PPV_2021','CIC_PPV_2022','CIC_NRC_2019','CIC_NRC_2020','CIC_NRC_2021',
         'CIC_NRC_2022','NIS_PPV_2019','NIS_PPV_2020','NIS_PPV_2021','NIS_PPV_2022','NIS_NRC_2019','NIS_NRC_2020',
         'NIS_NRC_2021','NIS_NRC_2022','PRS_PPV_2019','PRS_PPV_2020','PRS_PPV_2021','PRS_PPV_2022','PRS_NRC_2019',
         'PRS_NRC_2020','PRS_NRC_2021','PRS_NRC_2022','RCP_PPV_2019','RCP_PPV_2020','RCP_PPV_2021','RCP_PPV_2022',
         'RCP_NRC_2019','RCP_NRC_2020','RCP_NRC_2021','RCP_NRC_2022','Transverse gts_PPV_2019','Transverse gts_PPV_2020',
         'Transverse gts_PPV_2021','Transverse gts_PPV_2022','Transverse gts_NRC_2019','Transverse gts_NRC_2020',
         'Transverse gts_NRC_2021','Transverse gts_NRC_2022','MLS_PPV_2019','MLS_PPV_2020','MLS_PPV_2021','MLS_PPV_2022',
         'MLS_NRC_2019','MLS_NRC_2020','MLS_NRC_2021','MLS_NRC_2022','URS_PPV_2019','URS_PPV_2020','URS_PPV_2021',
         'URS_PPV_2022','URS_NRC_2019','URS_NRC_2020','URS_NRC_2021','URS_NRC_2022','ICS_PPV_2019','ICS_PPV_2020',
         'ICS_PPV_2021','ICS_PPV_2022','ICS_NRC_2019','ICS_NRC_2020','ICS_NRC_2021','ICS_NRC_2022','RCS_PPV_2019',
         'RCS_PPV_2020','RCS_PPV_2021','RCS_PPV_2022','RCS_NRC_2019','RCS_NRC_2020','RCS_NRC_2021','RCS_NRC_2022',
         'Transverse tas_PPV_2019','Transverse tas_PPV_2020','Transverse tas_PPV_2021','Transverse tas_PPV_2022',
         'Transverse tas_NRC_2019','Transverse tas_NRC_2020','Transverse tas_NRC_2021','Transverse tas_NRC_2022',
         'Telecom_PPV_2019','Telecom_PPV_2020','Telecom_PPV_2021','Telecom_PPV_2022','Telecom_NRC_2019','Telecom_NRC_2020',
         'Telecom_NRC_2021','Telecom_NRC_2022','OEN_PPV_2019','OEN_PPV_2020','OEN_PPV_2021','OEN_PPV_2022',
         'OEN_NRC_2019','OEN_NRC_2020','OEN_NRC_2021','OEN_NRC_2022','Transverse dis_PPV_2019','Transverse dis_PPV_2020',
         'Transverse dis_PPV_2021','Transverse dis_PPV_2022','Transverse dis_NRC_2019','Transverse dis_NRC_2020',
         'Transverse dis_NRC_2021','Transverse dis_NRC_2022','CPL_PPV_2019','CPL_PPV_2020','CPL_PPV_2021','CPL_PPV_2022',
         'CPL_NRC_2019','CPL_NRC_2020','CPL_NRC_2021','CPL_NRC_2022','AIS_PPV_2019','AIS_PPV_2020','AIS_PPV_2021',
         'AIS_PPV_2022','AIS_NRC_2019','AIS_NRC_2020','AIS_NRC_2021','AIS_NRC_2022','BPS_PPV_2019','BPS_PPV_2020',
         'BPS_PPV_2021','BPS_PPV_2022','BPS_NRC_2019','BPS_NRC_2020','BPS_NRC_2021','BPS_NRC_2022','IBS_PPV_2019',
         'IBS_PPV_2020','IBS_PPV_2021','IBS_PPV_2022','IBS_NRC_2019','IBS_NRC_2020','IBS_NRC_2021','IBS_NRC_2022',
         'MCS_PPV_2019','MCS_PPV_2020','MCS_PPV_2021','MCS_PPV_2022','MCS_NRC_2019','MCS_NRC_2020','MCS_NRC_2021',
         'MCS_NRC_2022']

variables = ['Transverse oth_PPV_2019','Transverse oth_PPV_2020','Transverse oth_PPV_2021','Transverse oth_PPV_2022',
         'Transverse oth_NRC_2019','Transverse oth_NRC_2020','Transverse oth_NRC_2021','Transverse oth_NRC_2022',
         'Transverse avs_PPV_2019','Transverse avs_PPV_2020','Transverse avs_PPV_2021','Transverse avs_PPV_2022',
         'Transverse avs_NRC_2019','Transverse avs_NRC_2020','Transverse avs_NRC_2021','Transverse avs_NRC_2022',
         'FLX_PPV_2019','FLX_PPV_2020','FLX_PPV_2021','FLX_PPV_2022','FLX_NRC_2019','FLX_NRC_2020','FLX_NRC_2021',
         'FLX_NRC_2022','IFE_PPV_2019','IFE_PPV_2020','IFE_PPV_2021','IFE_PPV_2022','IFE_NRC_2019','IFE_NRC_2020',
         'IFE_NRC_2021','IFE_NRC_2022','ELS_PPV_2019','ELS_PPV_2020','ELS_PPV_2021','ELS_PPV_2022','ELS_NRC_2019',
         'ELS_NRC_2020','ELS_NRC_2021','ELS_NRC_2022','MIS_PPV_2019','MIS_PPV_2020','MIS_PPV_2021','MIS_PPV_2022',
         'MIS_NRC_2019','MIS_NRC_2020','MIS_NRC_2021','MIS_NRC_2022','TTS_PPV_2019','TTS_PPV_2020','TTS_PPV_2021',
         'TTS_PPV_2022','TTS_NRC_2019','TTS_NRC_2020','TTS_NRC_2021','TTS_NRC_2022','Transverse las_PPV_2019',
         'Transverse las_PPV_2020','Transverse las_PPV_2021','Transverse las_PPV_2022','Transverse las_NRC_2019',
         'Transverse las_NRC_2020','Transverse las_NRC_2021','Transverse las_NRC_2022','ATM_PPV_2019','ATM_PPV_2020',
         'ATM_PPV_2021','ATM_PPV_2022','ATM_NRC_2019','ATM_NRC_2020','ATM_NRC_2021','ATM_NRC_2022','AOW_PPV_2019',
         'AOW_PPV_2020','AOW_PPV_2021','AOW_PPV_2022','AOW_NRC_2019','AOW_NRC_2020','AOW_NRC_2021','AOW_NRC_2022',
         'OME_PPV_2019','OME_PPV_2020','OME_PPV_2021','OME_PPV_2022','OME_NRC_2019','OME_NRC_2020','OME_NRC_2021',
         'OME_NRC_2022','VTS_PPV_2019','VTS_PPV_2020','VTS_PPV_2021','VTS_PPV_2022','VTS_NRC_2019','VTS_NRC_2020',
         'VTS_NRC_2021','VTS_NRC_2022','SRA_PPV_2019','SRA_PPV_2020','SRA_PPV_2021','SRA_PPV_2022','SRA_NRC_2019',
         'SRA_NRC_2020','SRA_NRC_2021','SRA_NRC_2022','Transverse dms_PPV_2019','Transverse dms_PPV_2020',
         'Transverse dms_PPV_2021','Transverse dms_PPV_2022','Transverse dms_NRC_2019','Transverse dms_NRC_2020',
         'Transverse dms_NRC_2021','Transverse dms_NRC_2022','AWS_PPV_2019','AWS_PPV_2020','AWS_PPV_2021','AWS_PPV_2022',
         'AWS_NRC_2019','AWS_NRC_2020','AWS_NRC_2021','AWS_NRC_2022','ECS_PPV_2019','ECS_PPV_2020','ECS_PPV_2021',
         'ECS_PPV_2022','ECS_NRC_2019','ECS_NRC_2020','ECS_NRC_2021','ECS_NRC_2022','ISR_PPV_2019','ISR_PPV_2020',
         'ISR_PPV_2021','ISR_PPV_2022','ISR_NRC_2019','ISR_NRC_2020','ISR_NRC_2021','ISR_NRC_2022','UWS_PPV_2019',
         'UWS_PPV_2020','UWS_PPV_2021','UWS_PPV_2022','UWS_NRC_2019','UWS_NRC_2020','UWS_NRC_2021','UWS_NRC_2022',
         'Transverse six_PPV_2019','Transverse six_PPV_2020','Transverse six_PPV_2021','Transverse six_PPV_2022',
         'Transverse six_NRC_2019','Transverse six_NRC_2020','Transverse six_NRC_2021','Transverse six_NRC_2022',
         'CIC_PPV_2019','CIC_PPV_2020','CIC_PPV_2021','CIC_PPV_2022','CIC_NRC_2019','CIC_NRC_2020','CIC_NRC_2021',
         'CIC_NRC_2022','NIS_PPV_2019','NIS_PPV_2020','NIS_PPV_2021','NIS_PPV_2022','NIS_NRC_2019','NIS_NRC_2020',
         'NIS_NRC_2021','NIS_NRC_2022','PRS_PPV_2019','PRS_PPV_2020','PRS_PPV_2021','PRS_PPV_2022','PRS_NRC_2019',
         'PRS_NRC_2020','PRS_NRC_2021','PRS_NRC_2022','RCP_PPV_2019','RCP_PPV_2020','RCP_PPV_2021','RCP_PPV_2022',
         'RCP_NRC_2019','RCP_NRC_2020','RCP_NRC_2021','RCP_NRC_2022','Transverse gts_PPV_2019','Transverse gts_PPV_2020',
         'Transverse gts_PPV_2021','Transverse gts_PPV_2022','Transverse gts_NRC_2019','Transverse gts_NRC_2020',
         'Transverse gts_NRC_2021','Transverse gts_NRC_2022','MLS_PPV_2019','MLS_PPV_2020','MLS_PPV_2021','MLS_PPV_2022',
         'MLS_NRC_2019','MLS_NRC_2020','MLS_NRC_2021','MLS_NRC_2022','URS_PPV_2019','URS_PPV_2020','URS_PPV_2021',
         'URS_PPV_2022','URS_NRC_2019','URS_NRC_2020','URS_NRC_2021','URS_NRC_2022','ICS_PPV_2019','ICS_PPV_2020',
         'ICS_PPV_2021','ICS_PPV_2022','ICS_NRC_2019','ICS_NRC_2020','ICS_NRC_2021','ICS_NRC_2022','RCS_PPV_2019',
         'RCS_PPV_2020','RCS_PPV_2021','RCS_PPV_2022','RCS_NRC_2019','RCS_NRC_2020','RCS_NRC_2021','RCS_NRC_2022',
         'Transverse tas_PPV_2019','Transverse tas_PPV_2020','Transverse tas_PPV_2021','Transverse tas_PPV_2022',
         'Transverse tas_NRC_2019','Transverse tas_NRC_2020','Transverse tas_NRC_2021','Transverse tas_NRC_2022',
         'Telecom_PPV_2019','Telecom_PPV_2020','Telecom_PPV_2021','Telecom_PPV_2022','Telecom_NRC_2019','Telecom_NRC_2020',
         'Telecom_NRC_2021','Telecom_NRC_2022','OEN_PPV_2019','OEN_PPV_2020','OEN_PPV_2021','OEN_PPV_2022',
         'OEN_NRC_2019','OEN_NRC_2020','OEN_NRC_2021','OEN_NRC_2022','Transverse dis_PPV_2019','Transverse dis_PPV_2020',
         'Transverse dis_PPV_2021','Transverse dis_PPV_2022','Transverse dis_NRC_2019','Transverse dis_NRC_2020',
         'Transverse dis_NRC_2021','Transverse dis_NRC_2022','CPL_PPV_2019','CPL_PPV_2020','CPL_PPV_2021','CPL_PPV_2022',
         'CPL_NRC_2019','CPL_NRC_2020','CPL_NRC_2021','CPL_NRC_2022','AIS_PPV_2019','AIS_PPV_2020','AIS_PPV_2021',
         'AIS_PPV_2022','AIS_NRC_2019','AIS_NRC_2020','AIS_NRC_2021','AIS_NRC_2022','BPS_PPV_2019','BPS_PPV_2020',
         'BPS_PPV_2021','BPS_PPV_2022','BPS_NRC_2019','BPS_NRC_2020','BPS_NRC_2021','BPS_NRC_2022','IBS_PPV_2019',
         'IBS_PPV_2020','IBS_PPV_2021','IBS_PPV_2022','IBS_NRC_2019','IBS_NRC_2020','IBS_NRC_2021','IBS_NRC_2022',
         'MCS_PPV_2019','MCS_PPV_2020','MCS_PPV_2021','MCS_PPV_2022','MCS_NRC_2019','MCS_NRC_2020','MCS_NRC_2021',
         'MCS_NRC_2022'] 

dataset_cleaned.select(lambda x: not re.search('Saving Objective\d+', x), axis = 1)
dataset_cleaned.select(lambda x: not re.search('NRC (M€)\d+', x), axis = 1)
dataset_cleaned.loc[:,~dataset_cleaned.columns.str.contains('^Saving Objective', case = False)] 
dataset_cleaned.loc[:,~dataset_cleaned.columns.str.contains('^NRC (M€)', case = False)] 
dataset_cleaned = dataset_cleaned.drop(dataset_cleaned.filter(regex = 'Saving Objective').columns, axis = 1)
dataset_cleaned = dataset_cleaned.drop(dataset_cleaned.filter(regex = 'NRC (M€)').columns, axis = 1)

unwanted = dataset_cleaned.columns[dataset_cleaned.columns.str.startswith('NRC (M€)')]
dataset_cleaned.drop(unwanted, axis = 1, inplace = True)


dataset_cleaned.columns = fields

df_melt = pd.melt(dataset_cleaned,
                       id_vars = ['Action_of_competitiveness','Seg','Cat']
                       #var_name = variables, 
                       #value_name = 'values')
                  )

df_melt = df_melt[df_melt.value != 0]



df_melt['Year'] = df_melt['variable'].str.extract('(\d+)').astype(int)
df_melt['BL'] = df_melt['variable'].str.extract('^([^_]*).*', expand = True)
df_melt['Metric'] = df_melt.variable.str.extract(r'_\s*([^\_]*)\s*\_', expand = True)

df_melt.rename(columns = {'value':'Value'}, inplace = True)
df_melt = df_melt.drop(['variable'], axis=1)

GBU_table = {'GBU': ['OTH','AVS','AVS','AVS','AVS','AVS','AVS','LAS','LAS','LAS','LAS',
                     'LAS','LAS','DMS','DMS','DMS','DMS','DMS','SIX','SIX','SIX','SIX',
                     'SIX','GTS','GTS','GTS','GTS','GTS','TAS','TAS','TAS','DIS','DIS',
                     'DIS','DIS','DIS','DIS'
                    ],
             
             'BL': ['Transverse oth','Transverse avs','FLX','IFE','ELS','MIS','TTS',
                     'Transverse las','ATM','AOW','OME','VTS','SRA','Transverse dms',
                     'AWS','ECS','ISR','UWS','Transverse six','CIC','NIS','PRS','RCP',
                     'Transverse gts','MLS','URS','ICS','RCS','Transverse tas','Telecom',
                     'OEN','Transverse dis','CPL','AIS','BPS','IBS','MCS'
                   ]
                    }

GBU_BL_table = pd.DataFrame(data = GBU_table)
merged_df_melt = df_melt[['Action_of_competitiveness',
                          'Seg',
                          'Cat',
                          'Value',
                          'Year',
                          'BL',
                          'Metric']].merge(GBU_BL_table[['GBU','BL']], on = 'BL', how = 'left')                 
                    

merged_df_melt['Seg'].replace(0, 'Undefined', inplace = True)
merged_df_melt['Cat'].replace(0, 'Undefined', inplace = True)
    
merged_df_melt.ndim
merged_df_melt.dtypes

#merged_df_melt['BL'] = merged_df_melt['BL'].replace({'Transverse':'Trans'})
#merged_df_melt['BL'] = merged_df_melt['BL'].replace('Transverse' ,'Trans')

merged_df_melt['BL'] = merged_df_melt['BL'].apply(lambda x: re.sub('Transverse','Trans', x))
#merged_df_melt.replace('Transverse ', 'Trans ', regex = True)
#merged_df_melt.replace(regex = ['Transverse'], value = 'Trans')

from IPython.display import display
display(merged_df_melt)

merged_df_melt.to_excel("D:\\Users\T0230575\Desktop\output.xlsx", index = False)
# Out:
# D:\APP\Anaconda3\lib\site-packages\ipykernel_launcher.py:132: FutureWarning: 'select' is deprecated and will be removed in a future release. You can use .loc[labels.map(crit)] as a replacement
# D:\APP\Anaconda3\lib\site-packages\ipykernel_launcher.py:133: FutureWarning: 'select' is deprecated and will be removed in a future release. You can use .loc[labels.map(crit)] as a replacement
# D:\APP\Anaconda3\lib\site-packages\ipykernel_launcher.py:135: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#                               Action_of_competitiveness Seg  Cat  \
# 0                 WAVE 1 - Travel - A2 Best Buy Offline   A  C10
# 1                  WAVE 1 - Travel - A2 BEST BUY ONLINE   A  C10
# 2        WAVE 1 - Travel - AIR 2nd year tactical review   A  C10
# 3                   WAVE 1 - Travel - Demand management   A  C10
# 4     WAVE 1 - Travel - F1 Travel Management Company...   A  C10
# ...
