# %%
import pandas as pd
import numpy as np
import os, sys
import glob
import time
from pathlib import Path

extension = "/*.csv"
path = 'C:/Users/T0230575/Desktop/Export JIRA/'
os.chdir('C:/Users/T0230575/Desktop/Export JIRA/')

latest_file = glob.glob(os.getcwd() + '/*.csv')
latest_df = max(latest_file, key = os.path.getctime)
print(latest_df)

jira_df = pd.read_csv(latest_df, sep='|', encoding='utf-8')
jira_df = jira_df[jira_df.columns.drop(list(jira_df.filter(regex='Champs personnalisés')))]
jira_df
# Out:
# C:\Users\T0230575\Desktop\Export JIRA\AJIR Thales 2021-03-17T13_41_45+0100.csv
#                                                Résumé Clé de ticket  \
# 0                                      DataLunch KAST      DALAB-25
# 1               Voir avec Florian Hadjhadj l'existant      DALAB-24
# 2                     proposer de nouveaux dashboards      DALAB-23
# 3                Création API Producteur-consommateur      DALAB-22
# 4                       Etablir l'analyse multi-vols       DALAB-21
# 5               Retranscrire les graphes en dashboard      DALAB-20
# 6                  Mettre en DB les données calculées      DALAB-19
# 7      Effectuer le retro-engineering des algorithmes      DALAB-18
# 8                     Mettre en DB les données brutes      DALAB-17
# 9                                   Modèle de données      DALAB-16
# 10                                 Macro Architecture      DALAB-15
# 11                                       Architecture      DALAB-14
# ...
